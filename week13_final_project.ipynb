# %%
import os
import epitran
os.chdir("/Users/Clair/machine_learning_sp20")

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
import pandas as pd
import string

# %%
langs = ["ara-Arab", "aze-Latn", "ben-Beng", "cat-Latn", "deu-Latn", "spa-Latn", "fra-Latn", "hun-Latn", 
         "ind-Latn", "ita-Latn", "mar-Deva", "msa-Latn", "mlt-Latn", "nld-Latn", "pol-Latn", "por-Latn", 
        "ron-Latn", "rus-Cyrl", "swe-Latn", "swa-Latn", "tam-Taml", "tel-Telu", "tha-Thai", "tuk-Latn",
       "tgl-Latn", "tur-Latn", "ukr-Cyrl", "uzb-Latn", "vie-Latn"]
abbrevs = ["ar", "az", "bn", "ca", "de", "es", "fr", "hu", "id", "it", "mr", "ms", "mt", "nl", 
           "pl", "pt", "ro", "ru", "sl","sw", "ta", "te", "th", "tk", "tl", "tr", "uk", "uz", "vi"]

# %%
columnNames = ["one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", 
               "eleven", "twelve", "thirteen", "fourteen", "fifteen", "sixteen", "seventeen", 
               "eighteen", "nineteen", "twenty", "twenty_one", "twenty_two", "twenty_three", 
               "twenty_four", "twenty_five", "twenty_six", "twenty_seven", "twenty_eight"]

# %%
def removeUnknownChars(words):
    for word in words:
        word = filter(lambda x: x in string.printable, word)
    return words
            
def readInFile(rel_path):
    text_file = open(rel_path, "r", encoding="utf8")
    words = text_file.read().split('\n')
    return words

def translit(words, lang):
    epi = epitran.Epitran(lang)
    ipa = []
    for word in words:
        ipa.append(epi.transliterate(word))
    return ipa

def buildNPath(abbrev):
    return "C:/Users/Clair/machine_learning_sp20/Final_Project/sentiment_lexicons/negative_words_" + abbrev + ".txt"

def buildPPath(abbrev):
    return "C:/Users/Clair/machine_learning_sp20/Final_Project/sentiment_lexicons/positive_words_" + abbrev + ".txt"

# %%
n_ipas = []
p_ipas = []

length = 0;
i = 0
for lang in langs:

    n_words = removeUnknownChars(readInFile(buildNPath(abbrevs[i])))
    p_words = removeUnknownChars(readInFile(buildPPath(abbrevs[i])))

    n_ipa = translit(n_words, lang)
    p_ipa = translit(p_words, lang)
    
    ln = len(max(n_ipa, key=len))
    lp = len(max(p_ipa, key=len))
    
    if (ln > length):
        length = ln
    if (lp > length):
        length = lp
    
    n_ipas.extend(n_ipa)
    p_ipas.extend(p_ipa)
    print("Lang =", abbrevs[i], "completed")

    i += 1;

    
#n_ipas.append(translit(buildNPath("zh"), "cmn-Hans"))
#p_ipas.append(translit(buildPPath("zh"), "cmn-Hans"))
# Out:
# Lang = ar completed
# Lang = az completed
# Lang = bn completed
# Lang = ca completed
# Lang = de completed
# Lang = es completed
# Lang = fr completed
# Lang = hu completed
# Lang = id completed
# Lang = it completed
# Lang = mr completed
# Lang = ms completed
# Lang = mt completed
# Lang = nl completed
# Lang = pl completed
# Lang = pt completed
# Lang = ro completed
# Lang = ru completed
# Lang = sl completed
# Lang = sw completed
# Lang = ta completed
# Lang = te completed
# Lang = th completed
# Lang = tk completed
# Lang = tl completed
# Lang = tr completed
# Lang = uk completed
# Lang = uz completed
# Lang = vi completed

# %%
def buildListFromWord(word):
    wlist = []
    for letter in word:
        wlist.append(letter)
    return wlist



n_list = []
p_list = []
for word in n_ipas:
    n_list.append(buildListFromWord(word))
    
for word in p_ipas:
    p_list.append(buildListFromWord(word))

# %%
print(len(p_list))
print(len(n_list))
# Out:
# 29570
# 45807

# %%
my_df = pd.DataFrame(n_list)
my_df.to_csv('neg_list.csv', encoding="utf-8", index=False, header=columnNames)

my_df = pd.DataFrame(p_list)
my_df.to_csv('pos_list.csv', encoding="utf-8", index=False)

# %%
p_list
# Out:
# [['b', 'i', 'ː', 'n'],
#  ['m', 'θ', 'l'],
#  ['a', 'ٔ', 'u', 'ː', 'l'],
#  ['n', 's', 'm', 'ة'],
#  ['a', 'ٔ', 'k', 'b', 'r'],
#  ['q', 'd', 'm'],
#  ['k', 'b', 'i', 'ː', 'r'],
#  ['b', 'a', 'ː', 's', 'm'],
#  ['ʕ', 'm', 'l'],
#  ['d', 'ˤ', 'm', 'n'],
#  ['a', 'l', 'u', 'ː', 't', 'ˤ', 'n', 'i', 'ː'],
#  ['k', 'ʔ', 'a', 's'],
#  ['a', 'ٔ', 'f', 'd', 'ˤ', 'l'],
#  ['a', 'ٔ', 'h', 'l'],
#  ['ʕ', 'h', 'd'],
#  ['k', 'θ', 'i', 'ː', 'r'],
#  ['d', '͡', 'ʒ', 'd', 'a', 'ː'],
#  ['ʕ', 'i', 'ː', 'n'],
#  ['a', 'ٔ', 'ʕ', 'l', 'ى'],
#  ['d', '͡', 'ʒ', 'd', 'i', 'ː', 'd'],
#  ['ħ', 's', 'n'],
#  ['i', 'ː', 'ʕ', 'm', 'l'],
#  ['d', '͡', 'ʒ', 'a', 'ː', 'i', 'ː', 'ٔ', 'z', 'ة'],
#  ['z', 'i', 'ː', 'a', 'ː', 'd', 'ة'],
#  ['r', 'ʔ', 'a', 's'],
#  ['t', 'ˤ', 'r', 'i', 'ː', 'q', 'ة'],
#  ['a', 'ٔ', 'ʕ', 'm', 'a', 'ː', 'l'],
#  ['s', 'ʕ', 'i', 'ː', 'd'],
#  ['m', 'ʃ', 'r', 'u', 'ː', 'ʕ'],
#  ['s', 'ˤ', 'a', 'ː', 'l', 'ħ'],
#  ['u', 'ː', 'ħ', 'd', 'ة'],
#  ['i', 'ː', 'u', 'ː', 'ٔ', 'd', 'i', 'ː'],
#  ['t', 'q', 'd', 'm'],
#  ['ʃ', 'x', 's', 'ˤ', 'i', 'ː', 'ة'],
#  ['t', 'ħ', 'q', 'i', 'ː', 'q'],
#  ['ð', 'ˤ', 'h', 'r'],
#  ['a', 'l'],
#  ['ħ', 'i', 'ː'],
#  ['t', 'ʔ', 'a', 'θ', 'i', 'ː', 'r'],
#  ['k', 'a', 'ː', 'm', 'l'],
#  ['t', 'ˤ', 'l', 'b'],
#  ['t', 'ħ', 'm', 'l'],
#  ['q', 'i', 'ː', 'm', 'ة'],
#  ['m', 'ʕ', 'l', 'u', 'ː', 'm', 'a', 'ː', 't'],
#  ['ʕ', 'l', 'a', 'ː', 'q', 'ة'],
#  ['q', 'i', 'ː', 'a', 'ː', 'd', 'ة'],
#  ['m', 'ʕ', 'd', 'l'],
#  ['s', 'r', 'ʕ', 'ة'],
#  ['u', 'ː', 'a', 'ː', 's', 'ʕ'],
#  ['ʕ', 'r', 'f'],
#  ['a', 'l', 'b', 'n', 'a', 'ː', 'ء'],
#  ['t', 'ħ', 'r', 'i', 'ː', 'r'],
#  ['ʕ', 'm', 'q'],
#  ['d', '͡', 'ʒ', 'm', 'a', 'ː', 'l'],
#  ['ħ', 'q'],
#  ['a', 'l', 'ʃ', 'x', 's', 'ˤ', 'i', 'ː', 'a', 'ː', 't'],
#  ['d', 'ʕ', 'm'],
#  ['m', 'ʕ', 'r', 'u', 'ː', 'f'],
#  ['ħ', 'm', 'a', 'ː', 'i', 'ː', 'ة'],
#  ['s', 'ˤ', 'l', 'a', 'ː', 'ħ'],
#  ['a', 'l', 't', 'ħ', 'k', 'm'],
#  ['t', 'q', 'd', 'r'],
#  ['r', 'f', 'ʕ'],
#  ['a', 'l', 'm', 'r', 'i', 'ː', 'd', 'ˤ'],
#  ['a', 'l', 'm', 'ʕ', 'r', 'f', 'ة'],
#  ['m', 'θ', 'a', 'ː', 'l'],
#  ['θ', 'a', 'ː', 'b', 't'],
#  ['a', 'l', 'm', 'q', 'd', 's'],
#  ['t', 'ʕ', 'i', 'ː', 'ʃ'],
#  ['m', 'i', 'ː', 'l'],
#  ['m', 'f', 'h', 'u', 'ː', 'm'],
#  ['m', 'b', 'a', 'ː', 'r', 'k'],
#  ['s', 'l', 'i', 'ː', 'm'],
#  ['a', 'ٔ', 'm', 'i', 'ː', 'n'],
#  ['s', 'i', 'ː', 'd'],
#  ['q', 'd', 'r', 'ة'],
#  ['ð', 'h', 'b'],
#  ['ʕ', 'l', 'a', 'ː', 'd', '͡', 'ʒ'],
#  ['n', 'm', 'u', 'ː', 'ð', 'd', '͡', 'ʒ'],
#  ['q', 'd', 'r'],
#  ['ħ', 'd', 'i', 'ː', 'θ'],
#  ['s', 'ˤ', 'ħ', 'i', 'ː', 'ħ'],
#  ['t', 'u', 'ː', 'f', 'i', 'ː', 'r'],
#  ['s', 'a', 'ː', 'l', 'm'],
#  ['ħ', 'q', 'q'],
#  ['q', 'm', 'ة'],
#  ['n', 'ð', 'ˤ', 'm'],
#  ['a', 'l', 'ð', 'h', 'b'],
#  ['d', '͡', 'ʒ', 'i', 'ː', 'd'],
#  ['s', 'b', 'q'],
#  ['s', 'h', 'l'],
#  ['ʃ', 'ɣ', 'l'],
#  ['n', 'd', '͡', 'ʒ', 'a', 'ː', 'ħ'],
#  ['ʃ', 'h', 'r', 'ة'],
#  ['ħ', 'f', 'ð', 'ˤ'],
#  ['t', 'ħ', 's', 'i', 'ː', 'n'],
#  ['x', 'i', 'ː', 'r'],
#  ['m', 'ʕ', 'r', 'd', 'ˤ'],
#  ['a', 'ʃ', 't', 'h', 'r'],
#  ['u', 'ː', 'a', 'ː', 'd', 'ˤ', 'ħ'],
#  ['m', 's', 'a', 'ː', 'ʕ', 'd', 'ة'],
#  ['s', 'ˤ', 'b', 'a', 'ː', 'ħ'],
#  ['a', 'ٔ', 'b', 't', 'ˤ', 'a', 'ː', 'l'],
#  ['r', 'i', 'ː', 'ٔ', 'i', 'ː', 's', 'i', 'ː'],
#  ['t', 'q', 'd', 'i', 'ː', 'r'],
#  ['k', 'm', 'a', 'ː', 'l'],
#  ['b', 't', 'ˤ', 'l'],
#  ['ħ', 'b'],
#  ['b', 'q', 'u', 'ː', 'ة'],
#  ['s', 'ˤ', 'ħ', 'ة'],
#  ['m', 'n', 'ħ'],
#  ['a', 'l', 'ʕ', 'q', 'l'],
#  ['ħ', 'r', 'i', 'ː', 'ة'],
#  ['b', 's', 'h', 'u', 'ː', 'l', 'ة'],
#  ['a', 'l', 'm', 'a', 'ː', 'd', '͡', 'ʒ', 's', 't', 'i', 'ː', 'r'],
#  ['a', 'ٔ', 'ʕ', 'ð', 'ˤ', 'm'],
#  ['q', 'u', 'ː', 'i', 'ː'],
#  ['q', 'a', 'ː', 'd'],
#  ['t', 'ħ', 's', 'ˤ', 'l'],
#  ['ʕ', 'm', 'l', 't'],
#  ['n', 's', 'ˤ', 'r'],
#  ['a', 'x', 't', 'l', 'a', 'ː', 'f'],
#  ['a', 'ٔ', 'q', 'u', 'ː', 'ى'],
#  ['h', 'z', 'i', 'ː', 'm', 'ة'],
#  ['s', 'l', 'a', 'ː', 'm'],
#  ['d', '͡', 'ʒ', 'm', 'i', 'ː', 'l'],
#  ['m', 'h', 'm'],
#  ['n', 'd', '͡', 'ʒ', 'ħ'],
#  ['a', 't', 'f', 'a', 'ː', 'q'],
#  ['ʃ', 'r', 'f'],
#  ['r', 'a', 'ː', 'ʃ', 'd'],
#  ['a', 'l', 'd', '͡', 'ʒ', 'u', 'ː', 'a', 'ː', 'i', 'ː', 'ٔ', 'z'],
#  ['b', 'i', 'ː', 'ٔ', 'r'],
#  ['i', 'ː', 't', 'd', '͡', 'ʒ', 'a', 'ː', 'u', 'ː', 'z'],
#  ['ʕ', 'a', 'ː', 'd', 'l'],
#  ['q', 'a', 'ː', 'b', 'l', 'ة'],
#  ['d', '͡', 'ʒ', 'm', 'i', 'ː', 'l', 'ة'],
#  ['a', 'ʕ', 't', 'b', 'a', 'ː', 'r'],
#  ['ħ', 'b', 'i', 'ː', 'b'],
#  ['r', 'd', 'ˤ', 'a', 'ː'],
#  ['r', 'ʕ', 'a', 'ː', 'i', 'ː', 'ة'],
#  ['t', 't', 'm', 't', 'ʕ'],
#  ['f', 'd', 'ˤ', 'l'],
#  ['b', 's', 'i', 'ː', 't', 'ˤ'],
#  ['a', 'l', 'd', '͡', 'ʒ', 'm', 'a', 'ː', 'l'],
#  ['d', 'ʕ', 'a', 'ː'],
#  ['t', 'u', 'ː', 'd', '͡', 'ʒ', 'i', 'ː', 'h'],
#  ['a', 'ٔ', 's', 'r', 'ʕ'],
#  ['i', 'ː', 't', 'm', 't', 'ʕ'],
#  ['m', 's', 't', 'q', 'l'],
#  ['s', 'r', 'i', 'ː', 'ʕ'],
#  ['h', 'a', 'ː', 'm'],
#  ['a', 'ٔ', 'θ', 'a', 'ː', 'r'],
#  ['s', 'a', 'ː', 'ʕ', 'd'],
#  ['q', 'i', 'ː', 'm'],
#  ['r', 'i', 'g', 'h', 't'],
#  ['a', 'ٔ', 'ħ', 's', 'n'],
#  ['a', 'ٔ', 'd', '͡', 'ʒ', 'm', 'l'],
#  ['θ', 'q', 'ة'],
#  ['r', 'i', 'ː', 'a', 'ː', 'd', 'ˤ', 'i', 'ː'],
#  ['b', 'd', 'q', 'ة'],
#  ['k', 'r', 'i', 'ː', 'm'],
#  ['a', 'ٔ', 'm', 'n'],
#  ['t', 'ʕ', 'z', 'i', 'ː', 'z'],
#  ['b', 'a', 'ː', 's', 't', 'm', 'r', 'a', 'ː', 'r'],
#  ['ʕ', 'ð', 'ˤ', 'i', 'ː', 'm'],
#  ['d', '͡', 'ʒ', 'd'],
#  ['a', 'l', 'n', 's', 'x'],
#  ['m', 'ħ', 's', 'n'],
#  ['ʃ', 'a', 'ː', 'b'],
#  ['t', 'u', 'ː', 'f', 'i', 'ː', 'q'],
#  ['d', 'q', 'ة'],
#  ['a', 'ٕ', 's', 'ˤ', 'l', 'a', 'ː', 'ħ'],
#  ['a', 'ٔ', 'k', 'd'],
#  ['a', 'l', 'd', '͡', 'ʒ', 'n', 'ة'],
#  ['ħ', 'm', 'a', 'ː', 's'],
#  ['i', 'ː', 'ħ', 'b'],
#  ['i', 'ː', 'k', 'f', 'i', 'ː'],
#  ['d', '͡', 'ʒ', 'i', 'ː', 'd', 'a', 'ː'],
#  ['d', 'q', 'i', 'ː', 'q'],
#  ['u', 'ː', 'a', 'ː', 'f', 'q'],
#  ['q', 'a', 'ː', 'd', 'r'],
#  ['m', 'n', 't', 'd', '͡', 'ʒ'],
#  ['r', 'ħ', 'm', 'ة'],
#  ['b', 'ħ', 'q'],
#  ['t', 't', 'd', '͡', 'ʒ', 'a', 'ː', 'u', 'ː', 'z'],
#  ['r', 'a', 'ː', 'i', 'ː', 'ٔ', 'ʕ', 'ة'],
#  ['s', 'k', 'n'],
#  ['a', 's', 't', 'b', 'd', 'a', 'ː', 'l'],
#  ['b', 'n', 'd', '͡', 'ʒ', 'a', 'ː', 'ħ'],
#  ['a', 'l', 'θ', 'q', 'ة'],
#  ['a', 'ٔ', 'm', 'l'],
#  ['f', 'ʕ', 'a', 'ː', 'l', 'i', 'ː', 'ة'],
#  ['a', 's', 't', 'q', 'r'],
#  ['h', 'z', 'm'],
#  ['a', 's', 't', 'ʕ', 'a', 'ː', 'd', 'ة'],
#  ['a', 'ٔ', 'd', 'b'],
#  ['s', 'r'],
#  ['n', 'f', 'u', 'ː', 'ð'],
#  ['i', 'ː', 'm', 'i', 'ː', 'n'],
#  ['m', 'l', 'ħ', 'u', 'ː', 'ð', 'ˤ'],
#  ['f', 'k', 'r'],
#  ['t', 'f', 'u', 'ː', 'q'],
#  ['t', 'ˤ', 'a', 'ː', 'h', 'r'],
#  ['b', 'a', 'ː', 'r', 'k'],
#  ['ʕ', 'l', 'a', 'ː', 'u', 'ː', 'ة'],
#  ['t', 'd', '͡', 'ʒ', 'a', 'ː', 'u', 'ː', 'z'],
#  ['ʃ', 'a', 'ː', 'm', 'l'],
#  ['a', 'l', 'm', 'd', 'a', 'ː', 'f', 'ʕ'],
#  ['f', 'ʕ', 'a', 'ː', 'l'],
#  ['u', 'ː', 't', 'ˤ', 'n', 'i', 'ː'],
#  ['l', 'f', 'ð', 'ˤ'],
#  ['f', 'u', 'ː', 'z'],
#  ['m', 'u', 'ː', 'a', 'ː', 'f', 'q', 'ة'],
#  ['t', 'ʔ', 'a', 'm', 'i', 'ː', 'n'],
#  ['m', 's', 'ˤ', 'l', 'ħ', 'ة'],
#  ['m', 'i', 'ː', 'z', 'ة'],
#  ['m', 'ʃ', 'h', 'u', 'ː', 'r'],
#  ['d', 'ˤ', 'm', 'a', 'ː', 'n'],
#  ['d', '͡', 'ʒ', 'ð', 'b'],
#  ['n', 'd', '͡', 'ʒ', 'ħ', 't'],
#  ['i', 'ː', 'θ', 'b', 't'],
#  ['ʕ', 'z', 'i', 'ː', 'z'],
#  ['a', 'ٕ', 'ħ', 'i', 'ː', 'a', 'ː', 'ء'],
#  ['m', 'n', 'a', 'ː', 's', 'b'],
#  ['f', 'a', 'ː', 'i', 'ː', 'ٔ', 'd', 'ة'],
#  ['a', 'n', 't', 's', 'ˤ', 'a', 'ː', 'r'],
#  ['b', 'a', 'ː', 'r', 'z'],
#  ['a', 'l', 'f', 'a', 'ː', 'i', 'ː', 'ٔ', 'z'],
#  ['b', 'u', 'ː', 'd', 'ˤ', 'u', 'ː', 'ħ'],
#  ['a', 'ٔ', 'ħ', 'b'],
#  ['a', 'l', 'f', 'd', '͡', 'ʒ', 'r'],
#  ['ʃ', 'a', 'ː', 'i', 'ː', 'ٔ', 'ʕ'],
#  ['t', 'u', 'ː', 'd', 'ˤ', 'i', 'ː', 'ħ'],
#  ['ħ', 'q', 'i', 'ː', 'q', 'i', 'ː'],
#  ['s', 'ˤ', 'a', 'ː', 'd', 'q'],
#  ['b', 'q', 'a', 'ː', 'ء'],
#  ['m', 'a', 'ː', 'd', '͡', 'ʒ', 's', 't', 'i', 'ː', 'r'],
#  ['t', 'ʃ', 'd', '͡', 'ʒ', 'i', 'ː', 'ʕ'],
#  ['i', 'ː', 'd', 'ʕ', 'm'],
#  ['z', 'a', 'ː', 'i', 'ː', 'd'],
#  ['a', 'q', 't', 's', 'ˤ', 'a', 'ː', 'd', 'i', 'ː'],
#  ['b', 'r', 'k', 'ة'],
#  ['ħ', 'r'],
#  ['f', 'd', '͡', 'ʒ', 'r'],
#  ['ʃ', 'a', 'ː', 'k', 'r'],
#  ['m', 's', 'ħ'],
#  ['t', 'θ', 'b', 't'],
#  ['s', 'i', 'ː', 'a', 'ː', 'd', 'ة'],
#  ['f', 'x', 'r'],
#  ['a', 's', 't', 'q', 'r', 'a', 'ː', 'r'],
#  ['r', 'a', 'ː', 'i', 'ː', 'ٔ', 'ʕ'],
#  ['s', 'a', 'ː', 'r'],
#  ['ħ', 'i', 'ː', 'u', 'ː', 'i', 'ː', 'ة'],
#  ['a', 'ٕ', 'n', 'd', '͡', 'ʒ', 'a', 'ː', 'z'],
#  ['ʕ', 'd', 'l'],
#  ['ʃ', 'ʕ', 'b', 'i', 'ː'],
#  ['a', 'ħ', 't', 'r', 'a', 'ː', 'm'],
#  ['s', 'h', 'u', 'ː', 'l', 'ة'],
#  ['a', 'l', 'ʔ', 'i', 's', 'ˤ', 'l', 'a', 'ː', 'ħ', 'a', 'ː', 't'],
#  ['n', 'b', 'i', 'ː', 'l'],
#  ['k', 'r', 'm'],
#  ['n', 'x', 'b', 'ة'],
#  ['a', 'ٓ', 'm', 'n'],
#  ['m', 'm', 'i', 'ː', 'z'],
#  ['a', 'r', 't', 'f', 'ʕ'],
#  ['a', 'ٕ', 'θ', 'a', 'ː', 'r', 'ة'],
#  ['m', 'n', 'ħ', 't'],
#  ['ɣ', 'n', 'ى'],
#  ['a', 'l', 'r', 'a', 'ː', 'i', 'ː', 'ٔ', 'd'],
#  ['m', 's', 'ˤ', 'a', 'ː', 'l', 'ħ'],
#  ['m', 's', 'k', 'n'],
#  ['q', 'a', 'ː', 'n', 'u', 'ː', 'n', 'i', 'ː'],
#  ['d', '͡', 'ʒ', 'u', 'ː', 'a', 'ː', 'd'],
#  ['t', 's', 'ˤ', 'ħ', 'i', 'ː', 'ħ'],
#  ['u', 'ː', 'ʕ', 'd'],
#  ['m', 's', 'ˤ', 'm', 'm'],
#  ['d', '͡', 'ʒ', 'i', 'ː', 'd', 'a', 'ː', 'ً'],
#  ['k', 's', 'b'],
#  ['a', 'ٔ', 's', 'ʕ', 'd'],
#  ['s', 'i', 'ː', 't', 'ˤ', 'r'],
#  ['t', 'm', 'a', 'ː', 'm'],
#  ['a', 'x', 't', 'r', 'a', 'ː', 'q'],
#  ['t', 'u', 'ː', 'a', 'ː', 'f', 'q'],
#  ['a', 'l', 'ʕ', 'a', 'ː', 'd', 'l'],
#  ['m', 'ʕ', 't', 'd', 'l'],
#  ['a', 'l', 's', 'u', 'ː', 'b', 'r'],
#  ['u', 'ː', 'ħ', 'i', 'ː'],
#  ['i', 'ː', 'n', 'd', '͡', 'ʒ', 'ħ'],
#  ['n', 'a', 'ː', 'f', 'ʕ'],
#  ['t', 'ˤ', 'i', 'ː', 'b'],
#  ['θ', 'r', 'u', 'ː', 'ة'],
#  ['t', 'ʔ', 'a', 'k', 'i', 'ː', 'd'],
#  ['h', 'a', 'ː', 'i', 'ː', 'ٔ', 'l'],
#  ['b', 'a', 'ː', 'l', 'd', 'ˤ', 'b', 't', 'ˤ'],
#  ['m', 'i', 'ː', 'θ', 'a', 'ː', 'q'],
#  ['ʕ', 'm', 'i', 'ː', 'q'],
#  ['n', 'h', 'd', 'ˤ', 'ة'],
#  ['a', 'l', 'm', 'ħ', 'm', 'u', 'ː', 'l'],
#  ['h', 'a', 'ː', 'd', 'i', 'ː'],
#  ['t', 'ɣ', 'l', 'b'],
#  ['a', 'l', 'r', 'd', 'ˤ', 'a', 'ː'],
#  ['a', 'l', 't', 'k', 'a', 'ː', 'm', 'l'],
#  ['m', 'l', 'k', 'i', 'ː'],
#  ['d', '͡', 'ʒ', 'd', 'd'],
#  ['t', 'ʃ', 'k', 'i', 'ː', 'l', 'ة'],
#  ['ħ', 'l', 'm'],
#  ['t', 'ħ', 's', 'n'],
#  ['h', 'u', 'ː', 'a', 'ː', 'ء'],
#  ['f', 'a', 'ː', 'd', 'ˤ', 'l'],
#  ['t', 'x', 'f', 'i', 'ː', 'f'],
#  ['m', 'd'],
#  ['m', 'm', 't', 'a', 'ː', 'z'],
#  ['m', 'r', 'a', 'ː', 'ʕ', 'a', 'ː', 'ة'],
#  ['ð', 'r', 'u', 'ː', 'ة'],
#  ['s', 'ˤ', 'ħ', 'i', 'ː'],
#  ['n', 'a', 'ː', 'd', '͡', 'ʒ', 'i', 'ː'],
#  ['f', 'r', 'd', 'i', 'ː', 'ة'],
#  ['k', 'a', 'ː', 'f'],
#  ['a', 'l', 'ʔ', 'a', 'm', 'θ', 'l'],
#  ['a', 'l', 'f', 'u', 'ː', 'a', 'ː', 'i', 'ː', 'ٔ', 'd'],
#  ['ʕ', 'z', 'm'],
#  ['m', 'z', 'a', 'ː', 'i', 'ː', 'a', 'ː'],
#  ['u', 'ː', 'a', 'ː', 'ħ', 'ة'],
#  ['t', 'f', 't', 'ħ'],
#  ['a', 'l', 'm', 'θ', 'a', 'ː', 'l', 'i', 'ː', 'ة'],
#  ['l', 'i', 'ː', 'n'],
#  ['ħ', 'k', 'i', 'ː', 'm'],
#  ['a', 'l', 'ħ', 'r', 'i', 'ː', 'a', 'ː', 't'],
#  ['m', 's', 'ˤ', 'i', 'ː', 'r'],
#  ['m', 'f', 'i', 'ː', 'd'],
#  ['ɣ', 'n', 'i', 'ː'],
#  ['n', 'ʃ', 't', 'ˤ'],
#  ['q', 'i', 'ː', 'a', 'ː', 'd', 'a', 'ː', 't'],
#  ['i', 'ː', 'f', 'u', 'ː', 'z'],
#  ['a', 'l', 'm', 's', 't', 'd', 'a', 'ː', 'm', 'ة'],
#  ['a', 'ٔ', 's', 'h', 'l'],
#  ['t', 'o', 'p'],
#  ['f', 'd', 'ˤ', 'i', 'ː', 'l', 'ة'],
#  ['m', 's', 't', 'q', 'i', 'ː', 'm'],
#  ['s', 'ˤ', 'f', 'q', 'ة'],
#  ['t', 'n', 'ʃ', 'i', 'ː', 't', 'ˤ'],
#  ['a', 'n', 't', 's', 'ˤ', 'r'],
#  ['t', 'k', 'r', 'i', 'ː', 'm'],
#  ['t', 'l', 'b', 'i', 'ː', 'ة'],
#  ['s', 'm', 'ʕ', 'ة'],
#  ['a', 'ٔ', 'm', 'a', 'ː', 'n', 'ة'],
#  ['ħ', 'q', 'a', 'ː'],
#  ['s', 'm', 'a', 'ː', 'ء'],
#  ['ħ', 'a', 'ː', 'r'],
#  ['m', 'n', 'ð', 'ˤ', 'm'],
#  ['s', 'ˤ', 'd', 'q'],
#  ['a', 'z', 'd', 'h', 'a', 'ː', 'r'],
#  ['i', 'ː', 'θ', 'i', 'ː', 'r'],
#  ['m', 't', 'm', 'i', 'ː', 'z'],
#  ['d', '͡', 'ʒ', 'a', 'ː', 'ð', 'b', 'i', 'ː', 'ة'],
#  ['a', 'ٕ', 'd', 'ˤ', 'a', 'ː', 'f', 'i', 'ː'],
#  ['n', 'ʕ', 'm', 'ة'],
#  ['m', 'a', 'ː', 'h', 'r'],
#  ['ʕ', 't', 'ˤ', 'a', 'ː', 'ء'],
#  ['a', 's', 't', 'ʕ', 'd', 'a', 'ː', 'd'],
#  ['a', 'ٔ', 'b', 's', 't', 'ˤ'],
#  ['a', 'k', 't', 's', 'b', 't'],
#  ['q', 'm', 'm'],
#  ['a', 'ٕ', 'i', 'ː', 'm', 'a', 'ː', 'n'],
#  ['a', 'ħ', 't', 'f', 'a', 'ː', 'l'],
#  ['d', 'a', 'ː', 'f', 'ʕ'],
#  ['b', 'r'],
#  ['b', 'r', 'q', 'ة'],
#  ['m', 't', 'k', 'a', 'ː', 'm', 'l'],
#  ['ʕ', 'm', 'l', 'i', 'ː'],
#  ['ʕ', 'ð', 'ˤ', 'm', 'ة'],
#  ['f', 'u', 'ː', 'r', 'a', 'ː'],
#  ['a', 'l', 't', 'ʔ', 'a', 'h', 'l'],
#  ['ħ', 'q', 'n'],
#  ['s', 'ˤ', 'd', 'a', 'ː', 'q', 'ة'],
#  ['a', 'l', 'm', 'θ', 'a', 'ː', 'l', 'i', 'ː'],
#  ['s', 'ʕ', 'a', 'ː', 'd', 'ة'],
#  ['q', 'd', 's'],
#  ['a', 'ħ', 'i', 'ː', 'a', 'ː', 'ء'],
#  ['m', 'q', 'b', 'u', 'ː', 'l'],
#  ['ʕ', 'ð', 'ˤ', 'm'],
#  ['t', 'ɣ', 'ð', 'i', 'ː', 'ة'],
#  ['ʃ', 'h', 'i', 'ː', 'r'],
#  ['a', 'l', 'ʔ', 'i', 'n', 'd', '͡', 'ʒ', 'a', 'ː', 'z', 'a', 'ː', 't'],
#  ['ħ', 'a', 'ː', 'z', 'm'],
#  ['ʃ', 'r', 'ʕ', 'i', 'ː'],
#  ['t', 'u', 'ː', 'd', '͡', 'ʒ'],
#  ['m', 'u', 'ː', 'h', 'b', 'ة'],
#  ['m', 'l', 'a', 'ː', 'k'],
#  ['m', 'h', 'a', 'ː', 'r', 'ة'],
#  ['ʃ', 'k', 'r'],
#  ['b', 'r', 'u', 'ː', 'z'],
#  ['r', 'f', 'i', 'ː', 'ʕ'],
#  ['m', 's', 't', 'q', 'r'],
#  ['a', 'b', 't', 'k', 'a', 'ː', 'r'],
#  ['f', 'r', 'ħ'],
#  ['m', 'ʃ', 'r', 'f'],
#  ['θ', 'u', 'ː', 'r'],
#  ['a', 'n', 'f', 's', 'ˤ', 'a', 'ː', 'l'],
#  ['a', 'l', 's', 'ˤ', 'a', 'ː', 'f', 'i', 'ː'],
#  ['a', 'l', 't', 'f', 'u', 'ː', 'q'],
#  ['t', 'f', 'd', 'ˤ', 'l'],
#  ['m', 'i', 'ː', 'm', 'u', 'ː', 'n'],
#  ['m', 'ʕ', 'a', 'ː', 's', 'ˤ', 'r'],
#  ['t', 'ʔ', 'a', 'i', 'ː', 'i', 'ː', 'd'],
#  ['a', 'l', 'd', 'u', 'ː', 'a', 'ː', 'm'],
#  ['t', 's', 't', 'ħ', 'q'],
#  ['n', 'a', 'ː', 'd', '͡', 'ʒ', 'ħ'],
#  ['r', 'a', 'ː', 'ħ', 'ة'],
#  ['b', 'ʕ', 'n', 'a', 'ː', 'i', 'ː', 'ة'],
#  ['a', 's', 't', 'f', 'a', 'ː', 'd'],
#  ['u', 'ː', 'd', 'ˤ', 'u', 'ː', 'ħ'],
#  ['u', 'ː', 'f', 'r', 'ة'],
#  ['a', 'ٕ', 'ʕ', 'd', '͡', 'ʒ', 'a', 'ː', 'b'],
#  ['m', 'd', 'ħ'],
#  ['a', 's', 't', 'ɣ', 'r', 'q'],
#  ['a', 'ٔ', 's', 'ˤ', 'ʕ', 'b'],
#  ['r', 'b', 'ħ'],
#  ['a', 'l', 't', 'z', 'a', 'ː', 'm'],
#  ['a', 'l', 'b', 'a', 'ː', 'r', 'z'],
#  ['x', 't', 'm'],
#  ['a', 'l', 'a', 'ː', 'ħ', 't', 'r', 'a', 'ː', 'm'],
#  ['ħ', 'b', 'i', 'ː', 'b', 'i', 'ː'],
#  ['a', 'ٔ', 'q', 'r'],
#  ['m', 'd', '͡', 'ʒ', 'a', 'ː', 'n', 'i', 'ː'],
#  ['d', 'ʕ', 'a', 'ː', 'ة'],
#  ['i', 'ː', 'ħ', 's', 'n'],
#  ['m', 'θ', 'i', 'ː', 'r'],
#  ['a', 'ٕ', 'ʃ', 'ʕ', 'a', 'ː', 'ʕ'],
#  ['r', 'ħ', 'm'],
#  ['d', '͡', 'ʒ', 'l', 'a', 'ː', 'l', 'ة'],
#  ['t', 't', 'f', 'q'],
#  ['s', 'ħ', 'r'],
#  ['a', 'l', 'm', 'f', 'i', 'ː', 'd'],
#  ['θ', 'r', 'i', 'ː'],
#  ['ʃ', 'd', '͡', 'ʒ', 'ʕ'],
#  ['t', 'ħ', 'f', 'ة'],
#  ['ħ', 'i', 'ː', 'a', 'ː'],
#  ['d', '͡', 'ʒ', 'm', 'l'],
#  ['x', 's', 'ˤ', 's', 'ˤ'],
#  ['ħ', 'k', 'm', 'ة'],
#  ['n', 'ʃ', 'i', 'ː', 'd'],
#  ['t', 'ħ', 'f', 'i', 'ː', 'z'],
#  ['a', 'ٔ', 'u', 'ː', 's', 'ˤ', 'ى'],
#  ['a', 'ٓ', 'd', 'a', 'ː', 'b'],
#  ['u', 'ː', 'n'],
#  ['d', '͡', 'ʒ', 'a', 'ː', 'd'],
#  ['a', 'ٔ', 'r', 'u', 'ː', 'ʕ'],
#  ['m', 'ħ', 'b', 'ة'],
#  ['b', 'k', 'f', 'a', 'ː', 'ء', 'ة'],
#  ['a', 'l', 'ʕ', 's', 'ˤ', 'r', 'i', 'ː', 'ة'],
#  ['m', 'u', 'ː', 'd', '͡', 'ʒ', 'b'],
#  ['m', 't', 'a', 'ː', 'ħ'],
#  ['a', 'ٔ', 'u', 'ː', 'd', '͡', 'ʒ'],
#  ['b', 's', 't', 'ˤ'],
#  ['f', 'r', 'e', 'e'],
#  ['r', 'u', 'ː', 'ħ', 'i', 'ː'],
#  ['a', 'l', 't', 'ħ', 'd', 'i', 'ː', 'θ'],
#  ['m', 'd', '͡', 'ʒ', 'd'],
#  ['i', 'ː', 'r', 'd', '͡', 'ʒ', 'ى'],
#  ['m', 'r', 'u', 'ː', 'n', 'ة'],
#  ['r', 't', 'b'],
#  ['a', 'ٔ', 'n', 'd', '͡', 'ʒ', 'ħ'],
#  ['m', 'θ', 'a', 'ː', 'l', 'i', 'ː'],
#  ['ʕ', 'd', '͡', 'ʒ', 'a', 'ː', 'i', 'ː', 'ٔ', 'b'],
#  ['m', 'ħ', 't', 'm', 'l'],
#  ['m', 't', 'u', 'ː', 'f', 'r'],
#  ['l', 't', 'ˤ', 'i', 'ː', 'f', 'ة'],
#  ['s', 'r', 'u', 'ː', 'r'],
#  ['t', 'm', 'k', 'i', 'ː', 'n'],
#  ['a', 'ٔ', 'ʕ', 'd', '͡', 'ʒ', 'b'],
#  ['ð', 'h', 'b', 'i', 'ː'],
#  ['d', '͡', 'ʒ', 'd', 'i', 'ː'],
#  ['l', 'l', 't', 'ħ', 'q', 'i', 'ː', 'q'],
#  ['a', 'l', 'm', 'u', 'ː', 'd', 'ˤ', 'u', 'ː', 'ʕ', 'i', 'ː', 'ة'],
#  ['r', 'k', 'b'],
#  ['a', 's', 't', 'r', 'd', 'a', 'ː', 'd'],
#  ['d', '͡', 'ʒ', 'l', 'i', 'ː', 'l'],
#  ['t', 'ʔ', 'a', 'l', 'q'],
#  ['l', 't', 'ˤ', 'i', 'ː', 'f'],
#  ['l', 'i', 'k', 'e'],
#  ['s', 'ˤ', 'ħ', 'i', 'ː', 'ħ', 'a', 'ː'],
#  ['ʃ', 'd', '͡', 'ʒ', 'a', 'ː', 'ʕ', 'ة'],
#  ['a', 'ٕ', 'i', 'ː', 'd', '͡', 'ʒ', 'a', 'ː', 'b', 'i', 'ː'],
#  ['a', 'ٔ', 'x', 'f'],
#  ['m', 'd', 'ˤ', 'r', 'b'],
#  ['t', 'r', 'q', 'i', 'ː', 'ة'],
#  ['m', 'n', 't', 'ˤ', 'q', 'i', 'ː'],
#  ['m', 'u', 'ː', 'θ', 'u', 'ː', 'q'],
#  ['ð', 'k', 'a', 'ː', 'ء'],
#  ['t', 'm', 'a', 'ː', 'θ', 'l'],
#  ['a', 'l', 't', 'ʕ', 'u', 'ː', 'i', 'ː', 'd', 'ˤ'],
#  ['a', 'ٔ', 'x', 'l', 'a', 'ː', 'q', 'i', 'ː', 'ة'],
#  ['m', 't', 'q', 'd', 'm'],
#  ['d', '͡', 'ʒ', 'n', 'ة'],
#  ['a', 's', 't', 'i', 'ː', 'ٔ', 'n', 'a', 'ː', 'f'],
#  ['b', 't', 'ˤ', 'l', 'ة'],
#  ['x', 'i', 'ː', 'r', 'ة'],
#  ['t', 'z', 'x', 'r'],
#  ['ħ', 's', 'n', 'a', 'ː'],
#  ['b', 'r', 'ʕ'],
#  ['ʕ', 'a', 'ː', 't', 'ˤ', 'f', 'i', 'ː', 'ة'],
#  ['m', 't', 'u', 'ː', 'a', 'ː', 'f', 'q', 'ة'],
#  ['t', 'ʕ', 'h', 'd'],
#  ['b', 'd', 'i', 'ː', 'ʕ'],
#  ['t', 'i', 'ː', 's', 'i', 'ː', 'r'],
#  ['ħ', 'θ'],
#  ['a', 'ٔ', 'l', 'm', 'ʕ'],
#  ['m', 'b', 'i', 'ː', 'n'],
#  ['s', 'ˤ', 'n', 'a', 'ː', 'ʕ'],
#  ['a', 'l', 's', 'ˤ', 'd', 'a', 'ː', 'r', 'ة'],
#  ['ħ', 'a', 'ː', 'd', 'ˤ', 'r'],
#  ['t', 'ð', 'k', 'a', 'ː', 'r', 'i', 'ː'],
#  ['m', 'd', '͡', 'ʒ', 'i', 'ː', 'd'],
#  ['m', 'u', 'ː', 'd', '͡', 'ʒ', 'z'],
#  ['k', 'r', 'a', 'ː', 'm', 'ة'],
#  ['m', 's', 't', 'q', 'b', 'l', 'i', 'ː', 'ة'],
#  ['ħ', 's', 'a', 'ː', 's'],
#  ['a', 'l', 'm', 'r', 'm', 'u', 'ː', 'q', 'ة'],
#  ['n', 'k', 'h', 'ة'],
#  ['a', 'l', 'f', 'a', 'ː', 'i', 'ː', 'ٔ', 'z', 'i', 'ː', 'n'],
#  ['ħ', 'd', 'a', 'ː', 'θ', 'ة'],
#  ['m', 'k', 'a', 'ː', 'f', 'ʔ', 'a', 'ة'],
#  ['m', 'u', 'ː', 'ٔ', 'θ', 'r'],
#  ['ʃ', 'f', 'a', 'ː', 'ء'],
#  ['ħ', 'ð', 'ˤ'],
#  ['b', 's', 'l', 'a', 'ː', 'm'],
#  ['r', 'd', 'ˤ', 'ى'],
#  ['a', 'ٔ', 'n', 'i', 'ː', 's'],
#  ['m', 'ħ', 'b'],
#  ['l', 'l', 'ʕ', 'r', 'd', 'ˤ'],
#  ['s', 'ˤ', 'r', 'i', 'ː', 'ħ'],
#  ['x', 's', 'ˤ', 'u', 'ː', 'b', 'ة'],
#  ['k', 'r', 's'],
#  ['d', '͡', 'ʒ', 'n', 's', 'i', 'ː'],
#  ['a', 'ٕ', 'l', 'h', 'a', 'ː', 'm'],
#  ['x', 'i', 'ː', 'r', 'i', 'ː'],
#  ['a', 'l', 't', 'm', 'a', 'ː', 's'],
#  ['t', 'ħ', 's', 'i', 'ː', 'n', 'a', 'ː', 't'],
#  ['a', 'ٔ', 'i', 'ː', 'd'],
#  ['i', 'ː', 'ʕ', 'z', 'z'],
#  ['m', 's', 'ˤ', 'd', 'a', 'ː', 'q', 'i', 'ː', 'ة'],
#  ['m', 't', 't', 'ˤ', 'u', 'ː', 'r'],
#  ['ɣ', 'z', 'i', 'ː', 'r'],
#  ['a', 'l', 'm', 'n', 'a', 'ː', 'u', 'ː', 'r', 'ة'],
#  ['w', 'o', 'r', 'k'],
#  ['ħ', 'l', 'u', 'ː'],
#  ['u', 'ː', 'a', 'ː', 'f', 'r'],
#  ['s', 'ˤ', 'ħ'],
#  ['ʃ', 'd', '͡', 'ʒ', 'a', 'ː', 'ʕ'],
#  ['n', 'ð', 'ˤ', 'i', 'ː', 'f'],
#  ['t', 'u', 'ː', 's', 'ˤ', 'i', 'ː', 'a', 'ː', 't'],
#  ['a', 'l', 'n', 'ʕ', 'i', 'ː', 'm'],
#  ['r', 'u', 'ː', 'a', 'ː', 'i', 'ː', 'ٔ', 'ʕ'],
#  ['a', 'ٔ', 's', 'ˤ', 'a', 'ː', 'l', 'ة'],
#  ['u', 'ː', 't', 'k', 'θ', 'r'],
#  ['a', 'ٕ', 'θ', 'r', 'a', 'ː', 'ء'],
#  ['m', 'l', 'a', 'ː', 'i', 'ː', 'ٔ', 'm'],
#  ['m', 'u', 'ː', 'ٔ', 'm', 'n'],
#  ['a', 'ٕ', 'ħ', 's', 'a', 'ː', 's'],
#  ['a', 'l', 'm', 'ʃ', 'd', '͡', 'ʒ', 'ʕ', 'i', 'ː', 'n'],
#  ['s', 'a', 'ː', 'x', 'n'],
#  ['m', 'u', 'ː', 'ٔ', 'i', 'ː', 'd'],
#  ['m', 'ʕ', 'd', '͡', 'ʒ', 'z', 'ة'],
#  ['f', 's', 'i', 'ː', 'ħ'],
#  ['m', 'u', 'ː', 'a', 'ː', 'h', 'b'],
#  ['k', 'n', 'z'],
#  ['n', 's', 'i', 'ː', 'm'],
#  ['s', 'ˤ', 'i', 'ː', 'a', 'ː', 'm'],
#  ['t', 'd', '͡', 'ʒ', 'd', 'd'],
#  ['t', 'u', 'ː', 'ٔ', 'i', 'ː', 'd'],
#  ['n', 'q', 'i', 'ː'],
#  ['n', 'a', 'ː', 'ʕ', 'm'],
#  ['t', 'ˤ', 'r', 'i', 'ː', 'f'],
#  ['θ', 'r', 'a', 'ː', 'ء'],
#  ['a', 'l', 'm', 'd', 'ʕ', 'u', 'ː', 'm', 'ة'],
#  ['m', 'r', 'n'],
#  ['m', 't', 'ʕ', 'ة'],
#  ['t', 'x', 'i', 'ː', 'l'],
#  ['i', 'm', 'p', 'o', 'r', 't', 'a', 'n', 't'],
#  ['q', 's', 'm', 'ة'],
#  ['ʕ', 'ʃ', 'q'],
#  ['ʕ', 'z', 'z'],
#  ['d', 'u', 'ː', 'a', 'ː', 'f', 'ʕ'],
#  ['a', 'l', 'n', 'b', 'i', 'ː', 'l'],
#  ['a', 'l', 'n', 'd', '͡', 'ʒ', 'a', 'ː', 'ħ', 'a', 'ː', 't'],
#  ['a', 'ٕ', 'n', 's', 'a', 'ː', 'n', 'i', 'ː'],
#  ['m', 'q', 'd', 's'],
#  ['t', 'ˤ', 'm', 'u', 'ː', 'ħ'],
#  ['r', 'ħ', 'b'],
#  ['h', 'd', 'u', 'ː', 'ء'],
#  ['b', 'a', 'ː', 'l', 't', 's', 'a', 'ː', 'u', 'ː', 'i', 'ː'],
#  ['b', 's'],
#  ['s', 'ˤ', 'b', 'r'],
#  ['a', 'n', 'k', 's', 'a', 'ː', 'r'],
#  ['a', 'l', 'm', 'f', 'a', 'ː', 'd', '͡', 'ʒ', 'i', 'ː', 'ٔ', 'ة'],
#  ['m', 's', 't', 'ʕ', 'd'],
#  ['b', 'h', 'd', 'u', 'ː', 'ء'],
#  ['b', 'x', 'i', 'ː', 'r'],
#  ['r', 'u', 'ː', 'ٔ', 'u', 'ː', 'f'],
#  ['d', 'b', 'l', 'u', 'ː', 'm', 'a', 'ː', 's', 'i', 'ː'],
#  ['m', 'ʕ', 'q', 'u', 'ː', 'l'],
#  ['a', 'ٔ', 'r', 'x', 's', 'ˤ'],
#  ['u', 'ː', 'l', 'a', 'ː', 'ء'],
#  ['ʕ', 'f', 'i', 'ː', 'f'],
#  ['ð', 'k', 'i', 'ː'],
#  ['u', 'ː', 'a', 'ː', 'q', 'ʕ', 'i', 'ː'],
#  ['f', 'a', 'ː', 'q'],
#  ['f', 'u', 'ː', 'r', 'i', 'ː'],
#  ['t', 'k', 'm', 'l', 'ة'],
#  ['i', 'ː', 'ʕ', 'l', 'u', 'ː'],
#  ['m', 'b', 't', 'k', 'r'],
#  ['a', 'l', 'ʔ', 'i', 'ʕ', 'd', '͡', 'ʒ', 'a', 'ː', 'b'],
#  ['b', 'a', 'ː', 'r', 'ʕ'],
#  ['n', 'a', 'ː', 'r', 'i', 'ː'],
#  ['ʕ', 'd', '͡', 'ʒ', 'b'],
#  ['b', 'l', 'i', 'ː', 'ɣ'],
#  ['ʃ', 'f', 'a', 'ː', 'f'],
#  ['r', 'u', 'ː', 'ʕ', 'ة'],
#  ['a', 'l', 'a', 'ː', 'n', 'x', 'r', 'a', 'ː', 't', 'ˤ'],
#  ['i', 'ː', 'x', 'f', 'f'],
#  ['h', 'a', 'ː', 'd', 'i', 'ː', 'ٔ'],
#  ['h', 'i', 'ː', 'b', 'ة'],
#  ['s', 'ˤ', 'f', 'a', 'ː', 'ء'],
#  ['r', 's', 'ˤ', 'a', 'ː', 's', 'ˤ'],
#  ['b', 'a', 'ː', 'ħ', 't', 'r', 'a', 'ː', 'm'],
#  ['ʕ', 'f', 'a', 'ː'],
#  ['r', 'ħ', 'i', 'ː', 'm'],
#  ['m', 'l', 'm', 'u', 'ː', 's'],
#  ['u', 'ː', 'd', 'i', 'ː'],
#  ['t', 'b', 's', 'i', 'ː', 't', 'ˤ'],
#  ['d', 'a', 'ː', 'f', 'i', 'ː', 'ٔ'],
#  ['b', 's', 'ˤ', 'm', 'a', 'ː', 't'],
#  ['t', 'u', 'ː', 's', 'ˤ', 'i', 'ː', 'ة'],
#  ['m', 'ħ', 'b', 'u', 'ː', 'b'],
#  ['s', 'm', 'a', 'ː', 'u', 'ː', 'i', 'ː'],
#  ['w', 'e', 'l', 'l'],
#  ['l', 'a', 'ː', 'm', 'ʕ'],
#  ['g', 'o', 'l', 'd'],
#  ['a', 'l', 'm', 's', 't', 'f', 'i', 'ː', 'd'],
#  ['s', 'l', 'm', 'i', 'ː'],
#  ['ħ', 'l', 'a', 'ː', 'u', 'ː', 'ة'],
#  ['a', 'l', 'ʕ', 'ʃ', 'q'],
#  ['ħ', 'b', 'i', 'ː', 'b', 'ة'],
#  ['a', 'ٔ', 'x', 'l', 'a', 'ː', 'q', 'i', 'ː'],
#  ['u', 's', 'e', 'f', 'u', 'l'],
#  ['ʕ', 'b', 'q', 'r', 'i', 'ː', 'ة'],
#  ['ħ', 'r', 'r'],
#  ['b', 'u', 'ː', 'f', 'r', 'ة'],
#  ['a', 'l', 'h', 'z', 'a', 'ː', 'i', 'ː', 'ٔ', 'm'],
#  ['s', 'a', 'ː', 'ħ', 'r'],
#  ['m', 'b', 's', 't', 'ˤ', 'ة'],
#  ['s', 'o', 'l', 'i', 'd'],
#  ['t', 'h', 'd', 'i', 'ː', 'ٔ', 'ة'],
#  ['i', 'ː', 's', 'r'],
#  ['m', 'h', 'i', 'ː', 'b'],
#  ['a', 'l', 'ʔ', 'i', 'x', 'l', 'a', 'ː', 's', 'ˤ'],
#  ['m', 'r', 'u', 'ː', 'ħ', 'ة'],
#  ['ɣ', 'a', 'ː', 'n', 'i', 'ː', 'ة'],
#  ['n', 'ð', 'ˤ', 'a', 'ː', 'f', 'ة'],
#  ['m', 'ħ', 'a', 'ː', 'm'],
#  ['θ', 'r', 'i', 'ː', 'a', 'ː'],
#  ['b', 't', 'f', 'u', 'ː', 'q'],
#  ['a', 'l', 'm', 'k', 'a', 'ː', 's', 'b'],
#  ['m', 'b', 'r', 'u', 'ː', 'k'],
#  ['a', 'ٕ', 'l', 'h', 'i', 'ː'],
#  ['f', 'a', 'ː', 't', 'n'],
#  ['r', 'ɣ', 'b'],
#  ['a', 'l', 'ʃ', 'd', '͡', 'ʒ', 'a', 'ː', 'ʕ'],
#  ['n', 'ʃ', 'i', 'ː', 't', 'ˤ'],
#  ['a', 'l', 'a', 'ː', 's', 't', 'd', 'a', 'ː', 'm', 'ة'],
#  ['m', 'd', '͡', 'ʒ', 's', 'm'],
#  ['d', '͡', 'ʒ', 'h', 'z'],
#  ['t', 'm', 'a', 'ː', 's', 'k'],
#  ['a', 'ħ', 't', 'f', 'l'],
#  ['q', 'i', 'ː', 'a', 'ː', 'd', 'i', 'ː'],
#  ['q', 'd', 'i', 'ː', 's'],
#  ['r', 'i', 'ː', 'a', 'ː'],
#  ['u', 'ː', 'r', 'd', 'i', 'ː'],
#  ['m', 'l', 'a', 'ː', 'ء', 'm', 'ة'],
#  ['s', 'ˤ', 'a', 'ː', 'm', 't'],
#  ['b', 'r', 'h', 'n'],
#  ['b', 'a', 'ː', 'l', 'ʕ', 'd', 'l'],
#  ['r', 'u', 'ː', 'm', 'a', 'ː', 'n', 's', 'i', 'ː'],
#  ['n', 'd', 'ˤ', 'd', '͡', 'ʒ'],
#  ['z', 'h', 'r'],
#  ['a', 'l', 'm', 'b', 't', 'k', 'r', 'ة'],
#  ['m', 'x', 'l', 's', 'ˤ'],
#  ['m', 't', 'u', 'ː', 'a', 'ː', 'd', 'ˤ', 'ʕ'],
#  ['a', 'l', 'm', 'b', 'd', 'i', 'ː', 'ٔ', 'i', 'ː'],
#  ['a', 'l', 'm', 'ʕ', 'd', '͡', 'ʒ', 'z', 'a', 'ː', 't'],
#  ['i', 'ː', 'b', 'r', 'd'],
#  ['l', 'm', 'ʕ'],
#  ['d', '͡', 'ʒ', 'a', 'ː', 'h', 'z'],
#  ['t', 'd', '͡', 'ʒ', 'm', 'i', 'ː', 'l'],
#  ['m', 'k', 'a', 'ː', 'f', 'i', 'ː', 'ٔ'],
#  ['ʕ', 'a', 'ː', 'ʃ', 'q'],
#  ['x', 'l', 's', 'ˤ'],
#  ['a', 'l', 'r', 'a', 'ː', 'q', 'i', 'ː'],
#  ['a', 's', 't', 'n', 'd'],
#  ['a', 'ٔ', 'n', 'ʕ', 'm'],
#  ['i', 'ː', 'ħ', 'f', 'z'],
#  ['m', 'd', 'ˤ', 'ɣ', 'u', 'ː', 't', 'ˤ'],
#  ['ħ', 'r', 'a', 'ː', 'n'],
#  ['a', 'z', 'd', 'h', 'r'],
#  ['ɣ', 'i', 'ː', 'r', 'i', 'ː'],
#  ['s', 'ˤ', 'q', 'l'],
#  ['a', 'l', 'm', 'u', 'ː', 'ٔ', 'h', 'l', 'i', 'ː', 'n'],
#  ['a', 'l', 'r', 'q', 'i', 'ː'],
#  ['a', 's', 't', 'f', 'a', 'ː', 'd', 'ة'],
#  ['a', 's', 't', 'θ', 'n', 'a', 'ː', 'i', 'ː', 'ٔ', 'i', 'ː'],
#  ['t', 's', 't', 'ʕ', 'd'],
#  ['b', 'r', 'a', 'ː', 'ʕ', 'ة'],
#  ['z', 'u', 'ː', 'r', 'q'],
#  ['d', 'a', 'ː', 'ʕ', 'm', 'ة'],
#  ['ħ', 'ð', 'ˤ', 'i', 'ː', 'r', 'ة'],
#  ['ħ', 'd', 'ˤ', 'n'],
#  ['b', 'd', '͡', 'ʒ', 'd'],
#  ['m', 'd', 'm', 'd', '͡', 'ʒ'],
#  ['f', 'a', 'ː', 'x', 'r'],
#  ['d', '͡', 'ʒ', 'u', 'ː', 'h', 'r', 'ة'],
#  ['b', 'a', 'ː', 'h', 'r'],
#  ['a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e'],
#  ['s', 'ʕ', 'i', 'ː'],
#  ['a', 'ٔ', 'ʕ', 'z'],
#  ['t', 'z', 'd', 'h', 'r'],
#  ['h', 'a', 'ː', 'd', 'f', 'ة'],
#  ['s', 'l', 's'],
#  ['d', 'ʕ', 'a', 'ː', 'm', 'ة'],
#  ['d', '͡', 'ʒ', 'd', 'a', 'ː', 'r', 'ة'],
#  ['u', 'ː', 's', 'i', 'ː', 'm'],
#  ['m', 'ʃ', 'd', '͡', 'ʒ', 'ʕ'],
#  ['b', 'θ', 'q', 'ة'],
#  ['m', 'n', 's', 'ˤ', 'f'],
#  ['b', 'ʃ', 'd', '͡', 'ʒ', 'a', 'ː', 'ʕ', 'ة'],
#  ['n', 's', 'ˤ', 'ħ'],
#  ['ʃ', 'ɣ', 'f'],
#  ['ʕ', 's', 'ˤ', 'r', 'i', 'ː'],
#  ['x', 's', 'ˤ', 'b'],
#  ['n', 'θ', 'r'],
#  ['m', 't', 'u', 'ː', 'a', 'ː', 'z', 'n'],
#  ['t', 'q', 'u', 'ː', 'ى'],
#  ['t', 's', 'ˤ', 'd', 'i', 'ː', 'q'],
#  ['b', 'h', 'd', '͡', 'ʒ', 'ة'],
#  ['a', 'l', 'm', 'r', 'ħ'],
#  ['f', 'd', 'a', 'ː', 'ء'],
#  ['d', '͡', 'ʒ', 'r', 'ʔ', 'a', 'ة'],
#  ['b', 's', 'ˤ', 'd', 'q'],
#  ['m', 's', 'b', 'b'],
#  ['u', 'ː', 'ʕ', 'u', 'ː', 'd'],
#  ['r', 'b', 'u', 'ː', 'ة'],
#  ['t', 't', 'f', 'u', 'ː', 'q'],
#  ['a', 'l', 'a', 'ː', 'n', 's', 'd', '͡', 'ʒ', 'a', 'ː', 'm'],
#  ['m', 'n', 'i', 'ː', 'ʕ'],
#  ['l', 'a', 'ː', 'i', 'ː', 'ٔ', 'q'],
#  ['t', 'ˤ', 'l', 'q'],
#  ['m', 'ʕ', 't', 'q', 'd'],
#  ['s', 'm', 't'],
#  ['d', 'f', 'q'],
#  ['m', 'k', 'r', 's', 'ة'],
#  ['m', 'r', 'i', 'ː', 'ħ'],
#  ['a', 'l', 'a', 'ː', 's', 't', 'm', 'r', 'a', 'ː', 'r', 'i', 'ː', 'ة'],
#  ['ʕ', 'f', 'u', 'ː'],
#  ['s', 'u', 'p', 'p', 'o', 'r', 't'],
#  ['m', 'ʃ', 'r', 'q'],
#  ['ʕ', 'a', 'ː', 'l', 'd', '͡', 'ʒ'],
#  ['ð', 'h', 'n', 'i', 'ː'],
#  ['f', 'a', 'i', 'r'],
#  ['n', 'i', 'ː', 'r'],
#  ['b', 'θ', 'b', 'a', 'ː', 't'],
#  ['t', 'x', 's', 'ˤ', 'i', 'ː', 'b'],
#  ['i', 'ː', 'h', 'i', 'ː', 'm', 'n'],
#  ['a', 'ٔ', 'm', 'l', 's'],
#  ['m', 't', 'i', 'ː', 'n'],
#  ['b', 'b', 'r', 'a', 'ː', 'ʕ', 'ة'],
#  ['a', 'ٕ', 'ʃ', 'b', 'a', 'ː', 'ʕ'],
#  ['i', 'ː', 't', 'f', 'u', 'ː', 'q'],
#  ['m', 'n', 'q', 'ð'],
#  ['b', 'ħ', 'r', 'a', 'ː', 'r', 'ة'],
#  ['a', 'ٔ', 'i', 'ː', 'd', 't'],
#  ['i', 'ː', 'f', 'i', 'ː'],
#  ['u', 'ː', 'a', 'ː', 'θ', 'q'],
#  ['m', 'q', 'n', 'ʕ'],
#  ['b', 'r', 'i', 'ː', 'q'],
#  ['a', 'ٔ', 's', 'ˤ', 'l', 'ħ'],
#  ['g', 'o', 'o', 'd'],
#  ['t', 'n', 'u', 'ː', 'ʕ', 'a', 'ː'],
#  ['a', 'l', 'k', 'θ', 'r', 'ة'],
#  ['a', 'ٔ', 'ħ', 'i', 'ː', 'a', 'ː'],
#  ['m', 'ʕ', 'd', '͡', 'ʒ', 'b'],
#  ['a', 'l', 'ʕ', 'd', '͡', 'ʒ', 'b'],
#  ['a', 'ٔ', 's', 'm', 'ى'],
#  ['d', '͡', 'ʒ', 'a', 'ː', 'i', 'ː', 'ٔ', 'z'],
#  ['a', 'ٔ', 's', 't', 'ˤ', 'u', 'ː', 'r', 'i', 'ː'],
#  ['m', 'ħ', 'b', 'u', 'ː', 'b', 'ة'],
#  ['k', 'l', 'a', 'ː', 's', 'i', 'ː', 'k', 'i', 'ː'],
#  ['t', 'ʕ', 'd', '͡', 'ʒ', 'b'],
#  ['b', 's', 'm', 'ة'],
#  ['b', 'ħ', 'm', 'a', 'ː', 's'],
#  ['a', 'l', 'ʔ', 'a', 'l', 'f', 'ة'],
#  ['m', 'ʃ', 'ʕ'],
#  ['a', 'n', 'f', 't', 'a', 'ː', 'ħ'],
#  ['ʕ', 'z', 'a', 'ː', 'ء'],
#  ['r', 'q', 'ة'],
#  ['a', 'l', 'ħ', 's', 'd'],
#  ['a', 'ٔ', 'r', 'q'],
#  ['u', 'ː', 'a', 'ː', 'ʕ', 'd'],
#  ['ʕ', 'a', 'ː', 't', 'ˤ', 'f', 'ة'],
#  ['x', 'f', 'f'],
#  ['b', 'ħ', 'k', 'm', 'ة'],
#  ['m', 'k', 'r', 'r'],
#  ['ʕ', 'a', 'ː', 'q', 'l'],
#  ['ʕ', 'a', 'ː', 't', 'ˤ', 'f', 'i', 'ː'],
#  ['ħ', 'r', 'r', 't'],
#  ['a', 'ħ', 't', 'd', 'ˤ', 'a', 'ː', 'n'],
#  ['m', 'u', 'ː', 'h', 'u', 'ː', 'b'],
#  ['m', 'ð', 'h', 'l'],
#  ['s', 'k', 't'],
#  ['t', 'f', 'u', 'ː', 'q', 't'],
#  ['a', 'n', 't', 'ʕ', 'a', 'ː', 'ʃ'],
#  ['a', 'l', 'ʃ', 'd', '͡', 'ʒ', 'ʕ', 'a', 'ː', 'n'],
#  ['u', 'ː', 'θ', 'q'],
#  ['d', 'h', 'ʃ', 'ة'],
#  ['t', 'd', 'ˤ', 'a', 'ː', 'm', 'n'],
#  ['m', 'k', 'm', 'l'],
#  ['d', '͡', 'ʒ', 'ð', 'a', 'ː', 'b'],
#  ['t', 'ʕ', 'a', 'ː', 'u', 'ː', 'n', 'i', 'ː'],
#  ['m', 'm', 't', 'ʕ'],
#  ['a', 'ٕ', 'ʕ', 'f', 'a', 'ː', 'ء'],
#  ['x', 'ʃ', 'i', 'ː'],
#  ['t', 'r', 'ħ', 'i', 'ː', 'b'],
#  ['a', 'l', 'm', 'ʃ', 'h', 'u', 'ː', 'd'],
#  ['a', 's', 't', 'q', 'a', 'ː', 'm', 'ة'],
#  ['a', 'l', 't', 'f', 'a', 'ː', 'u', 'ː', 'ٔ', 'l'],
#  ['i', 'ː', 'q', 'ð', 'ˤ', 'ة'],
#  ['l', 'a', 'ː', 'f', 't'],
#  ['s', 'a', 'ː', 'm', 'ى'],
#  ['s', 'a', 'ː', 't', 'ˤ', 'ʕ'],
#  ['i', 'ː', 'ħ', 'l', 'u', 'ː'],
#  ['b', 'r', 'ɣ', 'b', 'ة'],
#  ['a', 'i', 'ː', 'd', '͡', 'ʒ', 'a', 'ː', 'b', 'i', 'ː'],
#  ['d', 'i', 'ː', 'n', 'a', 'ː', 'm', 'i', 'ː', 'k', 'i', 'ː'],
#  ['b', 'ð', 'k', 'a', 'ː', 'ء'],
#  ['r', 'f', 'a', 'ː', 'h', 'i', 'ː', 'ة'],
#  ['a', 'l', 'm', 'ʕ', 'b', 'u', 'ː', 'd'],
#  ['m', 'ð', 'k', 'r'],
#  ['f', 't', 'n'],
#  ['a', 'l', 'ʔ', 'a', 'ħ', 'a', 'ː', 's', 'i', 'ː', 's'],
#  ['b', 'e', 's', 't'],
#  ['m', 'd', '͡', 'ʒ', 'a', 'ː', 'z'],
#  ['m', 'ʕ', 'z'],
#  ['m', 't', 'ˤ', 'a', 'ː', 'u', 'ː', 'ʕ'],
#  ['l', 't', 'ˤ', 'f'],
#  ['f', 's', 'ˤ', 'i', 'ː', 'ħ'],
#  ['t', 'u', 'ː', 'a', 'ː', 'd', 'ˤ', 'ʕ'],
#  ['b', 'r', 'q'],
#  ['a', 'n', 't', 'q', 'a', 'ː', 'i', 'ː', 'ٔ', 'i', 'ː'],
#  ['w', 'o', 'r', 'k', 's'],
#  ['s', 'ˤ', 'n', 'm'],
#  ['w', 'o', 'n'],
#  ['i', 'ː', 'b', 's', 't', 'ˤ'],
#  ['u', 'ː', 'q', 'a', 'ː', 'i', 'ː', 'ٔ', 'i', 'ː'],
#  ['a', 's', 't', 'x', 'b', 'a', 'ː', 'r', 'a', 'ː', 't'],
#  ['a', 'b', 't', 's', 'a', 'ː', 'm', 'ة'],
#  ['a', 'ٕ', 's', 'ˤ', 'l', 'a', 'ː', 'ħ', 'h'],
#  ['r', 'x', 'i', 'ː', 's', 'ˤ'],
#  ['ħ', 'f', 'z'],
#  ['t', 't', 'ˤ', 'l', 'ʕ', 'a', 'ː', 't'],
#  ['b', 'ʔ', 'a', 'm', 'a', 'ː', 'n', 'ة'],
#  ['ħ', 'm', 'a', 'ː', 's', 'ة'],
#  ['b', 'l', 't', 'ˤ', 'f'],
#  ['u', 'ː', 'd', 'ˤ', 'a', 'ː', 'ħ'],
#  ['m', 'f', 'd', 'ˤ', 'l', 'a', 'ː'],
#  ['ħ', 'n', 'u', 'ː', 'n'],
#  ['m', 'h', 'ð', 'b'],
#  ['ʕ', 'q', 'l', 'a', 'ː', 'n', 'i', 'ː'],
#  ['s', 'ħ', 'r', 'i', 'ː'],
#  ['i', 'ː', 'ʕ', 'h', 'd'],
#  ['n', 'a', 'ː', 'd', 'ˤ', 'd', '͡', 'ʒ'],
#  ['f', 'd', 'ˤ', 'u', 'ː', 'l'],
#  ['s', 'x', 'u', 'ː', 'n', 'ة'],
#  ['b', 's', 'ˤ', 'i', 'ː', 'r', 'ة'],
#  ['t', 'r', 'a', 'n', 's', 'p', 'a', 'r', 'e', 'n', 't'],
#  ['b', 'e', 't', 't', 'e', 'r'],
#  ['m', 'ħ', 't', 'r', 'm'],
#  ['r', 'ʃ', 'i', 'ː', 'q'],
#  ['a', 'n', 's', 'd', '͡', 'ʒ', 'a', 'ː', 'm'],
#  ['a', 't', 'z', 'a', 'ː', 'n'],
#  ['a', 'ٔ', 'ʃ', 'q', 'r'],
#  ['m', 'o', 'd', 'e', 'r', 'n'],
#  ['u', 'ː', 'l', 'ʕ'],
#  ['m', 'r', 'ħ'],
#  ['m', 'd', 'r', 'u', 'ː', 's'],
#  ['b', 'm', 's', 'u', 'ː', 'ٔ', 'u', 'ː', 'l', 'i', 'ː', 'ة'],
#  ['a', 'l', 'ʕ', 'z', 'i', 'ː', 'z', 'ة'],
#  ['m', 'n', 't', 's', 'ˤ', 'r'],
#  ['m', 't', 'm', 'a', 'ː', 's', 'k'],
#  ['u', 'ː', 'd', '͡', 'ʒ', 'i', 'ː', 'z'],
#  ['m', 'b', 'ʃ', 'r'],
#  ['f', 'x', 'm'],
#  ['r', 'd', 'h', 'a', 'ː'],
#  ['m', 'f', 'd', 'ˤ', 'l'],
#  ['a', 'l', 't', 'm', 'k', 'i', 'ː', 'n'],
#  ['m', 'd', '͡', 'ʒ', 't', 'h', 'd'],
#  ['b', 'ʔ', 'a', 'ʕ', 'd', '͡', 'ʒ', 'u', 'ː', 'b', 'ة'],
#  ['u', 'ː', 'u', 'ː', 'n'],
#  ['m', 's', 'm', 'u', 'ː', 'ʕ'],
#  ['t', 'n', 'u', 'ː', 'i', 'ː', 'r'],
#  ['a', 'ٔ', 'l', 'f', 'ة'],
#  ['r', 'a', 'ː', 'd', 'ˤ'],
#  ['t', 'q', 'd', 'i', 'ː', 'r', 'i', 'ː'],
#  ['t', 'r', 'f', 'i', 'ː', 'h'],
#  ['b', 'b', 's', 'a', 'ː', 'l', 'ة'],
#  ['a', 'd', '͡', 'ʒ', 't', 'h', 'a', 'ː', 'd'],
#  ['a', 'ٕ', 'x', 'l', 'a', 'ː', 's', 'ˤ'],
#  ['m', 'n', 'ʃ', 't', 'ˤ'],
#  ['t', 'd', 'a', 'ː', 'r', 'k'],
#  ['m', 'd', 'h', 'ʃ'],
#  ['t', 's', 't', 'k', 'm', 'l'],
#  ['c', 'l', 'e', 'a', 'r'],
#  ['n', 'f', 'i', 'ː', 's'],
#  ['m', 'h'],
#  ['m', 't', 'ʕ', 'l', 'm'],
#  ['l', 'i', 'ː', 'u', 'ː', 'n', 'ة'],
#  ['l', 'ð', 'i', 'ː', 'ð'],
#  ['t', 'm', 'd', '͡', 'ʒ', 'i', 'ː', 'd'],
#  ['a', 'ٕ', 'ʃ', 'a', 'ː', 'd', 'ة'],
#  ['r', 'u', 'ː', 'd', 'ˤ'],
#  ['ħ', 'r', 'i', 'ː', 's', 'ˤ'],
#  ['b', 'r', 'i', 'ː', 'ٔ'],
#  ['p', 'r', 'o', 't', 'e', 'c', 't', 'i', 'o', 'n'],
#  ['l', 'o', 'v', 'e'],
#  ['n', 'ʃ', 'u', 'ː', 'ة'],
#  ['d', 'a', 'ː', 'ʕ', 'm'],
#  ['ħ', 'm', 'i', 'ː', 'm'],
#  ['m', 't', 'd', '͡', 'ʒ', 'd', 'd'],
#  ['s', 'l', 'm', 'i', 'ː', 'a', 'ː'],
#  ['θ', 'm', 'i', 'ː', 'n'],
#  ['b', 's', 'l', 'a', 'ː', 's', 'ة'],
#  ['u', 'ː', 'r', 'ʕ'],
#  ['ħ', 'i', 'ː', 'i', 'ː'],
#  ['b', 'ʔ', 'i', 'x', 'l', 'a', 'ː', 's', 'ˤ'],
#  ['a', 's', 't', 'ʕ', 'd'],
#  ['a', 'ħ', 't', 'd', 'ˤ', 'n'],
#  ['m', 'ʃ', 'r', 'ʕ'],
#  ['ʕ', 'b', 'q'],
#  ['a', 'ٔ', 'l', 'h', 'm'],
#  ['t', 'r', 'u', 'ː'],
#  ['a', 'l', 'ʔ', 'a', 'n', 'i', 'ː', 'q'],
#  ['a', 'ٕ', 's', 'h', 'a', 'ː', 'm'],
#  ['m', 't', 'ʕ', 'h', 'd'],
#  ['t', 'q', 'd', 'm', 'i', 'ː', 'ة'],
#  ['b', 'u', 'ː', 'q'],
#  ['a', 'ٔ', 'n', 'i', 'ː', 'q'],
#  ['a', 'ٔ', 'ʕ', 'd', '͡', 'ʒ', 'u', 'ː', 'b', 'ة'],
#  ['m', 'u', 'ː', 'd', '͡', 'ʒ'],
#  ['m', 'ʕ', 's', 'ˤ', 'u', 'ː', 'm'],
#  ['z', 'f', 'r'],
#  ['a', 'l', 'm', 'k', 'a', 'ː', 'f', 'ʔ', 'a', 'ː', 't'],
#  ['a', 'ٔ', 'f', 'x', 'm'],
#  ['g', 'r', 'e', 'a', 't'],
#  ['a', 'p', 'p', 'r', 'o', 'p', 'r', 'i', 'a', 't', 'e'],
#  ['n', 'z', 'i', 'ː', 'h'],
#  ['m', 'm', 'r', 'd', 'ˤ'],
#  ['r', 'ʕ', 'ى'],
#  ['b', 's', 'x', 'a', 'ː', 'ء'],
#  ['a', 's', 't', 'm', 't', 'ʕ'],
#  ['m', 't', 'ħ', 'm', 's'],
#  ['b', 'x', 'b', 'r', 'ة'],
#  ['a', 'l', 'm', 't', 'f', 'u', 'ː', 'q'],
#  ['c', 'o', 'r', 'r', 'e', 'c', 't'],
#  ['h', 'a', 'ː', 'd', '͡', 'ʒ', 's'],
#  ['m', 't', 'b', 'r', 'ʕ'],
#  ['k', 'f', 'ى'],
#  ['k', 'b', 'r', 'i', 'ː', 'a', 'ː', 'ء'],
#  ['ʕ', 'f', 'u', 'ː', 'i', 'ː'],
#  ['s', 'ˤ', 'a', 'ː', 'f'],
#  ['x', 'f', 'f', 't'],
#  ['b', 'ʔ', 'i', 't', 'q', 'a', 'ː', 'n'],
#  ['m', 'n', 't', 's', 'ˤ', 'r', 'a', 'ː'],
#  ['m', 't', 'n', 'q', 'l'],
#  ['m', 't', 'f', 'u', 'ː', 'q'],
#  ['l', 'ð', 'i', 'ː', 'ð', 'ة'],
#  ['b', 'r', 'a', 'ː', 'q'],
#  ['a', 'l', 'a', 'ː', 'n', 'd', '͡', 'ʒ', 'ð', 'a', 'ː', 'b'],
#  ['i', 'ː', 'b', 't', 's', 'm'],
#  ['m', 's', 'ˤ', 'r', 'ħ'],
#  ['m', 'u', 'ː', 'ٔ', 'n', 's'],
#  ['b', 's', 'ʕ', 'a', 'ː', 'd', 'ة'],
#  ['a', 'ٔ', 'b', 'd', 'i', 'ː'],
#  ['p', 'r', 'o', 't', 'e', 'c', 't'],
#  ['f', 'x', 'u', 'ː', 'r'],
#  ['ħ', 's', 'n', 'a', 'ː', 'ء'],
#  ['m', 'k', 't', 's', 'b'],
#  ['r', 'ħ', 'm', 'n'],
#  ['a', 'l', 't', 'k', 'i', 'ː', 'f', 'i', 'ː', 'ة'],
#  ['a', 'l', 'a', 'ː', 'θ', 'a', 'ː', 'r', 'ة'],
#  ['a', 's', 'l', 'a', 'ː', 'm'],
#  ['u', 'ː', 'a', 'ː', 'θ', 'q', 'ة'],
#  ...]
