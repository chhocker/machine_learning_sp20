# %%
import os
import epitran
from sklearn import tree
from sklearn.model_selection import train_test_split
import pandas as pd
import string
os.chdir("/Users/Clair/machine_learning_sp20")

# %%
langs = ["ara-Arab", "aze-Latn", "ben-Beng", "cat-Latn", "deu-Latn", "spa-Latn", "fra-Latn", "hun-Latn", 
         "ind-Latn", "ita-Latn", "mar-Deva", "msa-Latn", "mlt-Latn", "nld-Latn", "pol-Latn", "por-Latn", 
        "ron-Latn", "rus-Cyrl", "swe-Latn", "swa-Latn", "tam-Taml", "tel-Telu", "tha-Thai", "tuk-Latn",
       "tgl-Latn", "tur-Latn", "ukr-Cyrl", "uzb-Latn", "vie-Latn"]
abbrevs = ["ar", "az", "bn", "ca", "de", "es", "fr", "hu", "id", "it", "mr", "ms", "mt", "nl", 
           "pl", "pt", "ro", "ru", "sl","sw", "ta", "te", "th", "tk", "tl", "tr", "uk", "uz", "vi"]

# %%
        
def readInFile(rel_path):
    text_file = open(rel_path, "r", encoding="utf-8")
    content = text_file.read()
    words = content.split('\n')
    text_file.close()
    return words

def translit(words, lang):
    epi = epitran.Epitran(lang)
    ipa = []
    for word in words:
        ipa.append(epi.transliterate(word))
    return ipa

def buildNPath(abbrev):
    return "C:/Users/Clair/machine_learning_sp20/Final_Project/sentiment_lexicons/negative_words_" + abbrev + ".txt"

def buildPPath(abbrev):
    return "C:/Users/Clair/machine_learning_sp20/Final_Project/sentiment_lexicons/positive_words_" + abbrev + ".txt"

# %%
n_ipas = []
p_ipas = []

length = 0;
i = 0

for lang in langs:

    n_words = readInFile(buildNPath(abbrevs[i]))
    p_words = readInFile(buildPPath(abbrevs[i]))

    n_ipa = translit(n_words, lang)
    p_ipa = translit(p_words, lang)
       
    n_ipas.extend(n_ipa)
    p_ipas.extend(p_ipa)
    print("Lang =", abbrevs[i], "completed")

    i += 1;
# Out:
# Lang = ar completed
# Lang = az completed
# Lang = bn completed
# Lang = ca completed
# Lang = de completed
# Lang = es completed
# Lang = fr completed
# Lang = hu completed
# Lang = id completed
# Lang = it completed
# Lang = mr completed
# Lang = ms completed
# Lang = mt completed
# Lang = nl completed
# Lang = pl completed
# Lang = pt completed
# Lang = ro completed
# Lang = ru completed
# Lang = sl completed
# Lang = sw completed
# Lang = ta completed
# Lang = te completed
# Lang = th completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3a7a40045807> in <module>
#      10     p_words = readInFile(buildPPath(abbrevs[i]))
#      11
# ---> 12     n_ipa = translit(n_words, lang)
#      13     p_ipa = translit(p_words, lang)
#      14
#
# <ipython-input-3-b406feb79057> in translit(words, lang)
#       7
#       8 def translit(words, lang):
# ----> 9     epi = epitran.Epitran(lang)
#      10     ipa = []
#      11     for word in words:
#
# ~\Anaconda3\lib\site-packages\epitran\_epitran.py in __init__(self, code, preproc, postproc, ligatures, cedict_file, rev, rev_preproc, rev_postproc)
#      46             self.epi = SimpleEpitran(code, preproc, postproc, ligatures, rev, rev_preproc, rev_postproc)
#      47         self.ft = panphon.featuretable.FeatureTable()
# ---> 48         self.xsampa = XSampa()
#      49         self.puncnorm = PuncNorm()
#      50
#
# ~\Anaconda3\lib\site-packages\epitran\xsampa.py in __init__(self)
#      20         """
#      21         self.trie = self._read_ipa2xs()
# ---> 22         self.ft = panphon.FeatureTable()
#      23
#      24     def _read_ipa2xs(self):
#
# ~\Anaconda3\lib\site-packages\panphon\featuretable.py in __init__(self, feature_set)
#      26         bases_fn, weights_fn = feature_sets[feature_set]
#      27         self.weights = self._read_weights(weights_fn)
# ---> 28         self.segments, self.seg_dict, self.names = self._read_bases(bases_fn, self.weights)
#      29         self.seg_regex = self._build_seg_regex()
#      30         self.longest_seg = max([len(x) for x in self.seg_dict.keys()])
#
# ~\Anaconda3\lib\site-packages\panphon\featuretable.py in _read_bases(self, fn, weights)
#      43                 vec = Segment(names,
#      44                               {n: v for (n, v) in zip(names, vals)},
# ---> 45                               weights=weights)
#      46                 segments.append((ipa, vec))
#      47         seg_dict = dict(segments)
#
# ~\Anaconda3\lib\site-packages\panphon\segment.py in __init__(self, names, features, ftstr, weights)
#      20             """
#      21         self.n2s = {-1: '-', 0: '0', 1: '+'}
# ---> 22         self.s2n = {k: v for (v, k) in self.n2s.items()}
#      23         self.names = names
#      24         """Set a feature specification"""
#
# ~\Anaconda3\lib\site-packages\panphon\segment.py in <dictcomp>(.0)
#      20             """
#      21         self.n2s = {-1: '-', 0: '0', 1: '+'}
# ---> 22         self.s2n = {k: v for (v, k) in self.n2s.items()}
#      23         self.names = names
#      24         """Set a feature specification"""
#
# KeyboardInterrupt:

# %%
comb_chars = []
    
for i in range(42752, 42783):
    comb_chars.append(chr(i))
    
for i in range(688, 879):
    comb_chars.append(chr(i))

# %%
up_sym = '\u0361'
colon_sym = '\u02D0'

def is_combo_char(char):
    return (char in comb_chars)

def has_combo_char(word):
    for letter in word:
        if is_combo_char(letter):
            return True;
    return False;

def split(word): 
    return [char for char in word]

# %%
def get_up_token(word, index):
    return word[index] + word[index + 1] + word[index + 2]

def get_combo_token(word, index):
    return word[index] + word[index + 1]

def get_list_with_up_symb(word):
    new_word_lst = []
    i = 0
    while (i < len(word)):
        if (i + 1 < len(word) and word[i + 1] == up_sym):
            new_word_lst.append(get_up_token(word, i))
            i += 3
        else:
            new_word_lst.append(word[i])
            i += 1
            
    return new_word_lst

def get_list_with_combo(word):
    new_word_lst = []
    i = 0
    while (i < len(word)):
        if (i + 1 < len(word) and is_combo_char(word[i + 1])):
            new_word_lst.append(get_col_token(word, i))
            i += 2
        else:
            new_word_lst.append(word[i])
            i += 1
            
    return new_word_lst

# %%
word = n_ipas[3] + n_ipas[67] + n_ipas[3]
word_id = 44
word_as_list = []

us_count = word.count(up_sym)
has_combo = has_combo_char(word)
word_as_list = split(word)        

if (us_count > 0 or has_combo):
    if (us_count > 0):
        word_as_list = get_list_with_up_symb(word_as_list)
    if (has_combo):
        word_as_list = get_list_with_combo(word_as_list)

# %%
n_list = []
p_list = []

wordId = 0

for i in range(len(n_ipas)):
    word = n_ipas[i]

    us_count = word.count(up_sym)
    has_combo = has_combo_char(word)
    word_as_list = split(word)        

    if (us_count > 0 or has_combo):
        if (us_count > 0):
            word_as_list = get_list_with_up_symb(word_as_list)
        if (has_combo):
            word_as_list = get_list_with_combo(word_as_list)

    n_list.append([wordId] + word_as_list)
    wordId += 1
    symbCount = 0

wordId = 0
for i in range(len(p_ipas)):
    word = p_ipas[i]

    us_count = word.count(up_sym)
    has_combo = has_combo_char(word)
    word_as_list = split(word)        

    if (us_count > 0 or has_combo):
        if (us_count > 0):
            word_as_list = get_list_with_up_symb(word_as_list)
        if (has_combo):
            word_as_list = get_list_with_combo(word_as_list)

    p_list.append([wordId] + word_as_list)
    wordId += 1
    symbCount = 0

# %%
my_df = pd.DataFrame(n_list)
my_df.to_csv('negative.csv', encoding="utf-8", index=False, header=False)

# %%
my_df = pd.DataFrame(p_list)
my_df.to_csv('positive.csv', encoding="utf-8", index=False, header=False)

# %%
pc4 = pd.read_csv("count_neg_3.csv", header=None, encoding="utf-8")
pf4 = pd.read_csv("conf_neg_3.csv", header=None, encoding="utf-8")
print("COUNT")
print(pc4[:6][0])
print(pc4[:6][1])
# Out:
# COUNT
# 0                        lhs
# 1           {"<U+0361>","i"}
# 2    {"<U+0283>","<U+0361>"}
# 3           {"<U+0361>","s"}
# 4    {"<U+0255>","<U+0361>"}
# 5           {"<U+0255>","t"}
# Name: 0, dtype: object
# 0             rhs
# 1           {"t"}
# 2           {"t"}
# 3           {"t"}
# 4           {"t"}
# 5    {"<U+0361>"}
# Name: 1, dtype: object

# %%
pc4 = pd.read_csv("count_pos_4.csv", header=None)
pf4 = pd.read_csv("conf_pos_4.csv", header=None)

pc5 = pd.read_csv("count_pos_5.csv", header=None)
pf5 = pd.read_csv("conf_pos_5.csv", header=None)

pc6 = pd.read_csv("count_pos_6.csv", header=None)
pf6 = pd.read_csv("conf_pos_6.csv", header=None)

print("COUNT")
print(pc4[:6][0])
print(pc4[:6][1])
print(pc4[:6][3])
print(pc4[:6][6])

print(pc5[:6][0])
print(pc5[:6][1])
print(pc5[:6][3])
print(pc5[:6][6])

print(pc6[:6][0])
print(pc6[:6][1])
print(pc6[:6][3])
print(pc6[:6][6])

print("CONFIDENCE")
print(pf4[:6][0])
print(pf4[:6][1])
print(pf4[:6][3])
print(pf4[:6][6])

print(pf5[:6][0])
print(pf5[:6][1])
print(pf5[:6][3])
print(pf5[:6][6])

print(pf6[:6][0])
print(pf6[:6][1])
print(pf6[:6][3])
print(pf6[:6][6])
# Out:
# COUNT
# 0                     lhs
# 1    {"<U+0361>","a","i"}
# 2    {"<U+0361>","i","n"}
# 3    {"<U+0361>","i","s"}
# 4    {"<U+0361>","a","n"}
# 5    {"<U+0361>","n","s"}
# Name: 0, dtype: object
# 0      rhs
# 1    {"t"}
# 2    {"t"}
# 3    {"t"}
# 4    {"t"}
# 5    {"t"}
# Name: 1, dtype: object
# 0           confidence
# 1    0.864197530864197
# 2    0.863328822733424
# 3    0.949152542372881
# 4    0.809840425531915
# 5    0.913312693498452
# Name: 3, dtype: object
# 0    count
# 1      700
# 2      638
# 3      616
# 4      609
# 5      590
# Name: 6, dtype: object
# 0                                lhs
# 1           {"<U+0361>","a","i","n"}
# 2           {"<U+0361>","i","n","s"}
# 3           {"<U+0361>","e","i","n"}
# 4           {"<U+0361>","e","i","s"}
# 5    {"<U+0283>","<U+0361>","a","i"}
# Name: 0, dtype: object
# 0      rhs
# 1    {"t"}
# 2    {"t"}
# 3    {"t"}
# 4    {"t"}
# 5    {"t"}
# Name: 1, dtype: object
# 0           confidence
# 1     0.85286783042394
# 2    0.943786982248521
# 3    0.882857142857143
# 4    0.973941368078176
# 5    0.996551724137931
# Name: 3, dtype: object
# 0    count
# 1      342
# 2      319
# 3      309
# 4      299
# 5      289
# Name: 6, dtype: object
# 0                      lhs
# 1    {"a","e","i","n","s"}
# 2    {"e","i","n","s","t"}
# 3    {"a","e","i","s","t"}
# 4    {"a","e","n","s","t"}
# 5    {"e","i","n","o","s"}
# Name: 0, dtype: object
# 0      rhs
# 1    {"t"}
# 2    {"a"}
# 3    {"n"}
# 4    {"i"}
# 5    {"a"}
# Name: 1, dtype: object
# 0           confidence
# 1    0.585470085470085
# 2    0.507407407407407
# 3    0.544731610337972
# 4    0.629885057471264
# 5    0.589108910891089
# Name: 3, dtype: object
# 0    count
# 1      274
# 2      274
# 3      274
# 4      274
# 5      238
# Name: 6, dtype: object
# CONFIDENCE
# 0                                   lhs
# 1           {"<U+0292>","<U+0361>","l"}
# 2           {"<U+0255>","<U+0361>","v"}
# 3    {"<U+0255>","<U+02B2>","<U+0361>"}
# 4           {"<U+0268>","<U+0361>","s"}
# 5           {"<U+0255>","<U+0361>","j"}
# Name: 0, dtype: object
# 0      rhs
# 1    {"d"}
# 2    {"t"}
# 3    {"t"}
# 4    {"t"}
# 5    {"t"}
# Name: 1, dtype: object
# 0    confidence
# 1             1
# 2             1
# 3             1
# 4             1
# 5             1
# Name: 3, dtype: object
# 0    count
# 1      196
# 2      196
# 3      184
# 4      179
# 5      179
# Name: 6, dtype: object
# 0                                lhs
# 1    {"<U+0283>","<U+0361>","e","s"}
# 2    {"<U+0283>","<U+0361>","a","i"}
# 3    {"<U+0283>","<U+0361>","a","e"}
# 4    {"<U+0283>","<U+0361>","e","l"}
# 5    {"<U+0283>","<U+0361>","i","r"}
# Name: 0, dtype: object
# 0      rhs
# 1    {"t"}
# 2    {"t"}
# 3    {"t"}
# 4    {"t"}
# 5    {"t"}
# Name: 1, dtype: object
# 0           confidence
# 1                    1
# 2    0.996551724137931
# 3    0.995515695067265
# 4    0.993670886075949
# 5    0.993670886075949
# Name: 3, dtype: object
# 0    count
# 1      152
# 2      289
# 3      222
# 4      157
# 5      157
# Name: 6, dtype: object
# 0                      lhs
# 1    {"a","e","i","o","s"}
# 2    {"a","e","n","o","s"}
# 3    {"a","e","n","s","t"}
# 4    {"a","e","n","r","t"}
# 5    {"a","e","i","n","r"}
# Name: 0, dtype: object
# 0      rhs
# 1    {"n"}
# 2    {"i"}
# 3    {"i"}
# 4    {"i"}
# 5    {"t"}
# Name: 1, dtype: object
# 0           confidence
# 1    0.734567901234568
# 2    0.662952646239554
# 3    0.629885057471264
# 4    0.626984126984127
# 5            0.6171875
# Name: 3, dtype: object
# 0    count
# 1      238
# 2      238
# 3      274
# 4      237
# 5      237
# Name: 6, dtype: object

# %%
lets = ["B", "C", "D", "F", "G", "H", "J", "K", "L", "M", "N", "P", "Q", "R", "S", "T", "V", "X", "Z", "w"]

for i in range(len(lets)):
    lets[i] = lets[i].lower()
lets
# Out:
# ['b',
#  'c',
#  'd',
#  'f',
#  'g',
#  'h',
#  'j',
#  'k',
#  'l',
#  'm',
#  'n',
#  'p',
#  'q',
#  'r',
#  's',
#  't',
#  'v',
#  'x',
#  'z',
#  'w']
